# %% [markdown]
# # again, I have to give a big shout out to Roopa and study group. I absolutely wouldn't have gotten this far without Roopa's link and then the ladies in study group bringing it on home.

# %% [markdown]
# ![home.png](attachment:home.png)

# %% [markdown]
# ![all.png](attachment:all.png)

# %% [markdown]
# ![year%20and%20forms%20to%20add.png](attachment:year%20and%20forms%20to%20add.png)

# %% [markdown]
# ![add%20new.png](attachment:add%20new.png)

# %% [markdown]
# ![see%20additions.png](attachment:see%20additions.png)

# %% [markdown]
# 2.	What kind of API did you build? What types of APIs are there? Why are APIs important?

# %% [markdown]
# I want to say that since we did the GET/POST that it is a REST API
#
# What types are there? I've found two groups of types of APIs.
# The Web APIs: Open, Partner, Internal and Composite
#
# or are you looking for REST, SOAP, RPC, and gRPC?
#
# Why are they important?
# IT seems like they are good for sharing resources, allowing people to build off of the work of others, and for allowing different programs to communicate.
