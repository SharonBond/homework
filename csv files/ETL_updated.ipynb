# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats

# %%
apikey = "15B191E7-B8C5-3AF1-9E28-97FD910F9119"
usda_url ="http://quickstats.nass.usda.gov/api/api_GET/?key=15B191E7-B8C5-3AF1-9E28-97FD910F9119&source_desc=SURVEY&commodity_desc=HONEY&agg_level_desc=STATE&param=short_desc"
usda_data= requests.get(usda_url).json()
usda_data
# Out:
# {'data': [{'location_desc': 'ALABAMA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ALABAMA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'AL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '01',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '5.43',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '01'},
#   {'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AL',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '01',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ALABAMA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ALABAMA',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'Value': '3.38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2019,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '01',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE'},
#   {'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ALABAMA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ALABAMA',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '01',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'AL',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '01',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '3.72',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2018,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY'},
#   {'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.18',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '04',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'AZ',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '04',
#    'location_desc': 'ARIZONA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ARIZONA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB'},
#   {'watershed_desc': '',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '04',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'AZ',
#    'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ARIZONA',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ARIZONA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '04',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.04',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2019,
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000'},
#   {'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '04',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '3.01',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2018,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '04',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'AZ',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ARIZONA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ARIZONA'},
#   {'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ARKANSAS',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'ARKANSAS',
#    'freq_desc': 'ANNUAL',
#    'watershed_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_ansi': '05',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AR',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '05',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '1.8',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2020,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY'},
#   {'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'location_desc': 'ARKANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ARKANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '05',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'AR',
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '05',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.65',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2019},
#   {'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'state_ansi': '05',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'AR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2020-03-19 15:06:59',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_name': 'ARKANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'ARKANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '05',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.88',
#    'zip_5': '',
#    'year': 2018,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB'},
#   {'state_ansi': '06',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_alpha': 'CA',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2021-03-18 15:00:29',
#    'state_name': 'CALIFORNIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'CALIFORNIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_fips_code': '06',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.78',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB'},
#   {'state_ansi': '06',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'CA',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'CALIFORNIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'CALIFORNIA',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '06',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2019,
#    'zip_5': '',
#    'Value': '1.6',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'agg_level_desc': 'STATE',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'country_code': '9000'},
#   {'state_ansi': '06',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'CA',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2020-03-19 15:06:59',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'location_desc': 'CALIFORNIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'CALIFORNIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '06',
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2018,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.11',
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000'},
#   {'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.09',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '08',
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'CO',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_ansi': '08',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'COLORADO',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'COLORADO',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY'},
#   {'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '08',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2019,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.34',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'location_desc': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'COLORADO',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_ansi': '08',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'CO',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': ''},
#   {'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '08',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'CO',
#    'load_time': '2020-03-19 15:06:59',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'location_desc': 'COLORADO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'COLORADO',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '08',
#    'Value': '2.05',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2018,
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'country_code': '9000'},
#   {'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '12',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '2.28',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2020,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'commodity_desc': 'HONEY',
#    'state_ansi': '12',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'FL',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'FLORIDA',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'location_desc': 'FLORIDA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'location_desc': 'FLORIDA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'FLORIDA',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '12',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'FL',
#    'agg_level_desc': 'STATE',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'congr_district_code': '',
#    'county_name': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '12',
#    'Value': '2.46',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2019,
#    'zip_5': ''},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'FLORIDA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'FLORIDA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'FL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '12',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.4',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2018,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '12'},
#   {'country_code': '9000',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.36',
#    'zip_5': '',
#    'year': 2020,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '13',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_name': 'GEORGIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'GA',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '13'},
#   {'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '13',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'GA',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'GEORGIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'GEORGIA',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '13',
#    'Value': '2.67',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2019,
#    'zip_5': '',
#    'agg_level_desc': 'STATE',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'country_code': '9000'},
#   {'state_name': 'GEORGIA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'GEORGIA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2020-03-19 15:06:59',
#    'state_alpha': 'GA',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_ansi': '13',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'year': 2018,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.76',
#    'state_fips_code': '13',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': ''},
#   {'Value': '1.61',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2020,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '15',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'HI',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '15',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'HAWAII',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'HAWAII',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR'},
#   {'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'state_name': 'HAWAII',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'HAWAII',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_ansi': '15',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'state_alpha': 'HI',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'state_fips_code': '15',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'zip_5': '',
#    'year': 2019,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.3'},
#   {'state_alpha': 'HI',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_ansi': '15',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'HAWAII',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'HAWAII',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2020-03-19 15:06:59',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2018,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.92',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '15',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE'},
#   {'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2020,
#    'zip_5': '',
#    'Value': '1.75',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '16',
#    'congr_district_code': '',
#    'county_name': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IDAHO',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'IDAHO',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'state_alpha': 'ID',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_ansi': '16',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL'},
#   {'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '16',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '1.62',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2019,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'IDAHO',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'IDAHO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'region_desc': '',
#    'state_ansi': '16',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ID'},
#   {'location_desc': 'IDAHO',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'IDAHO',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2020-03-19 15:06:59',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'ID',
#    'watershed_desc': '',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '16',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '1.96',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2018,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '16'},
#   {'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '5.56',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '17',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'IL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '17',
#    'location_desc': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'ILLINOIS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB'},
#   {'state_alpha': 'IL',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_ansi': '17',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'region_desc': '',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ILLINOIS',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'year': 2019,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'Value': '4.12',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '17',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE'},
#   {'state_alpha': 'IL',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_ansi': '17',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'ILLINOIS',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'ILLINOIS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2020-03-19 15:06:59',
#    'year': 2018,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'Value': '4.83',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'state_fips_code': '17',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE'},
#   {'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'IN',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '18',
#    'location_desc': 'INDIANA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'INDIANA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '4.14',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2020,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '18',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE'},
#   {'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '18',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'Value': '3.78',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2019,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_ansi': '18',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'IN',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'INDIANA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'INDIANA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2018,
#    'zip_5': '',
#    'Value': '3.58',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '18',
#    'congr_district_code': '',
#    'county_name': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'IN',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_ansi': '18',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'INDIANA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'INDIANA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2020-03-19 15:06:59',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00'},
#   {'Value': '2.59',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2020,
#    'zip_5': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '19',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'IA',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '19',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IOWA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'IOWA',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IOWA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'IOWA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2021-03-18 15:00:29',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'IA',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '19',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.35',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2019,
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '19'},
#   {'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2018,
#    'zip_5': '',
#    'Value': '2.4',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '19',
#    'congr_district_code': '',
#    'county_name': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'unit_desc': '$ / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'state_alpha': 'IA',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_ansi': '19',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'IOWA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'IOWA',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'load_time': '2020-03-19 15:06:59',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY'},
#   {'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.93',
#    'zip_5': '',
#    'year': 2020,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '20',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'agg_level_desc': 'STATE',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'KS',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '20',
#    'state_name': 'KANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'KANSAS',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR'},
#   {'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'year': 2019,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '2.35',
#    'state_fips_code': '20',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'asd_code': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_name': 'KANSAS',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'KANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'state_alpha': 'KS',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_ansi': '20',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': ''},
#   {'state_fips_code': '20',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'year': 2018,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'Value': '3.1',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '20',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_alpha': 'KS',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2020-03-19 15:06:59',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'KANSAS',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'KANSAS',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES'},
#   {'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'state_ansi': '21',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'KY',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_name': 'KENTUCKY',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'KENTUCKY',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'CV (%)': '',
#    'asd_code': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '21',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '6.25',
#    'zip_5': '',
#    'year': 2020,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'unit_desc': '$ / LB',
#    'county_ansi': ''},
#   {'state_fips_code': '21',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'asd_code': '',
#    'CV (%)': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'year': 2019,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'Value': '4.66',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'state_ansi': '21',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'state_alpha': 'KY',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2021-03-18 15:00:29',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'KENTUCKY',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'KENTUCKY'},
#   {'Value': '5.43',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2018,
#    'zip_5': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '21',
#    'county_ansi': '',
#    'unit_desc': '$ / LB',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'KY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'commodity_desc': 'HONEY',
#    'freq_desc': 'ANNUAL',
# ...
#    'watershed_code': '00000000',
#    'agg_level_desc': 'STATE',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_alpha': 'ND',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'state_ansi': '38',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'NORTH DAKOTA',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR'},
#   {'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'state_fips_code': '38',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'Value': '138',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'year': 2009,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'NORTH DAKOTA',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'state_ansi': '38',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'ND'},
#   {'state_ansi': '38',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'load_time': '2012-01-01 00:00:00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'NORTH DAKOTA',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '38',
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2008,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '136',
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'country_code': '9000'},
#   {'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'agg_level_desc': 'STATE',
#    'zip_5': '',
#    'year': 2007,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '96',
#    'state_fips_code': '38',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'NORTH DAKOTA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2012-01-01 00:00:00',
#    'state_alpha': 'ND',
#    'asd_desc': '',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'state_ansi': '38',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'commodity_desc': 'HONEY'},
#   {'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'ND',
#    'freq_desc': 'ANNUAL',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'state_ansi': '38',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '91',
#    'zip_5': '',
#    'year': 2006,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '38',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'load_time': '2012-01-01 00:00:00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'NORTH DAKOTA',
#    'state_ansi': '38',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'watershed_desc': '',
#    'region_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'ND',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'agg_level_desc': 'STATE',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'watershed_code': '00000000',
#    'country_code': '9000',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '38',
#    'congr_district_code': '',
#    'county_name': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'year': 2005,
#    'zip_5': '',
#    'Value': '83',
#    'statisticcat_desc': 'PRICE RECEIVED'},
#   {'state_ansi': '38',
#    'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'state_alpha': 'ND',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_name': 'NORTH DAKOTA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'state_fips_code': '38',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'CV (%)': '',
#    'asd_code': '',
#    'congr_district_code': '',
#    'county_name': '',
#    'year': 2004,
#    'zip_5': '',
#    'county_code': '',
#    'source_desc': 'SURVEY',
#    'Value': '105',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'watershed_code': '00000000'},
#   {'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'state_fips_code': '38',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'zip_5': '',
#    'year': 2003,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '136',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_ansi': '38',
#    'freq_desc': 'ANNUAL',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'state_alpha': 'ND',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS'},
#   {'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB',
#    'country_code': '9000',
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '38',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '146',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 2002,
#    'load_time': '2012-01-01 00:00:00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '38',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'class_desc': 'ALL CLASSES',
#    'asd_desc': '',
#    'state_alpha': 'ND'},
#   {'freq_desc': 'ANNUAL',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_ansi': '38',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'state_alpha': 'ND',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'load_time': '2012-01-01 00:00:00',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'NORTH DAKOTA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'state_fips_code': '38',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '69',
#    'zip_5': '',
#    'year': 2001,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': ''},
#   {'state_ansi': '38',
#    'freq_desc': 'ANNUAL',
#    'commodity_desc': 'HONEY',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'watershed_desc': '',
#    'state_alpha': 'ND',
#    'asd_desc': '',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'reference_period_desc': 'MARKETING YEAR',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'load_time': '2012-01-01 00:00:00',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_fips_code': '38',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'asd_code': '',
#    'CV (%)': '',
#    'county_name': '',
#    'congr_district_code': '',
#    'zip_5': '',
#    'year': 2000,
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '57',
#    'agg_level_desc': 'STATE',
#    'country_code': '9000',
#    'watershed_code': '00000000',
#    'county_ansi': '',
#    'unit_desc': 'CENTS / LB'},
#   {'watershed_code': '00000000',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 1999,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '59',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '38',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'week_ending': '',
#    'country_name': 'UNITED STATES',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'load_time': '2012-01-01 00:00:00',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_ansi': '38',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'region_desc': '',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL'},
#   {'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'location_desc': 'NORTH DAKOTA',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'load_time': '2012-01-01 00:00:00',
#    'group_desc': 'SPECIALTY',
#    'end_code': '00',
#    'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'state_alpha': 'ND',
#    'watershed_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'region_desc': '',
#    'commodity_desc': 'HONEY',
#    'freq_desc': 'ANNUAL',
#    'state_ansi': '38',
#    'watershed_code': '00000000',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'agg_level_desc': 'STATE',
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '63',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 1998,
#    'county_name': '',
#    'congr_district_code': '',
#    'CV (%)': '',
#    'asd_code': '',
#    'domain_desc': 'TOTAL',
#    'begin_code': '00',
#    'state_fips_code': '38'},
#   {'reference_period_desc': 'MARKETING YEAR',
#    'short_desc': 'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#    'load_time': '2012-01-01 00:00:00',
#    'end_code': '00',
#    'group_desc': 'SPECIALTY',
#    'location_desc': 'NORTH DAKOTA',
#    'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#    'country_name': 'UNITED STATES',
#    'week_ending': '',
#    'state_name': 'NORTH DAKOTA',
#    'domaincat_desc': 'NOT SPECIFIED',
#    'state_ansi': '38',
#    'region_desc': '',
#    'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#    'commodity_desc': 'HONEY',
#    'watershed_desc': '',
#    'freq_desc': 'ANNUAL',
#    'state_alpha': 'ND',
#    'class_desc': 'ALL CLASSES',
#    'sector_desc': 'ANIMALS & PRODUCTS',
#    'asd_desc': '',
#    'agg_level_desc': 'STATE',
#    'watershed_code': '00000000',
#    'unit_desc': 'CENTS / LB',
#    'county_ansi': '',
#    'country_code': '9000',
#    'begin_code': '00',
#    'domain_desc': 'TOTAL',
#    'state_fips_code': '38',
#    'county_name': '',
#    'congr_district_code': '',
#    'asd_code': '',
#    'CV (%)': '',
#    'source_desc': 'SURVEY',
#    'county_code': '',
#    'zip_5': '',
#    'year': 1997,
#    'statisticcat_desc': 'PRICE RECEIVED',
#    'Value': '74'},
#   ...]}

# %%
new_usda_list=usda_data['data']
usda_df=pd.DataFrame(new_usda_list)
usda_df.head(2)
usda_df.head(2)
# Out:
#   location_desc       prodn_practice_desc week_ending   country_name  \
# 0       ALABAMA  ALL PRODUCTION PRACTICES              UNITED STATES
# 1       ALABAMA  ALL PRODUCTION PRACTICES              UNITED STATES
#
#   state_name domaincat_desc            load_time end_code group_desc  \
# 0    ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29       00  SPECIALTY
# 1    ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29       00  SPECIALTY
#
#   reference_period_desc  ... county_code zip_5  year county_name  \
# 0        MARKETING YEAR  ...                    2020
# 1        MARKETING YEAR  ...                    2019
#
#   congr_district_code CV (%) asd_code begin_code domain_desc state_fips_code
# 0                                             00       TOTAL              01
# 1                                             00       TOTAL              01
#
# [2 rows x 39 columns]

# %%
usda_df.columns
# Out:
# Index(['location_desc', 'prodn_practice_desc', 'week_ending', 'country_name',
#        'state_name', 'domaincat_desc', 'load_time', 'end_code', 'group_desc',
#        'reference_period_desc', 'short_desc', 'sector_desc', 'class_desc',
#        'asd_desc', 'state_alpha', 'util_practice_desc', 'commodity_desc',
#        'region_desc', 'watershed_desc', 'freq_desc', 'state_ansi',
#        'watershed_code', 'unit_desc', 'county_ansi', 'country_code',
#        'agg_level_desc', 'statisticcat_desc', 'Value', 'source_desc',
#        'county_code', 'zip_5', 'year', 'county_name', 'congr_district_code',
#        'CV (%)', 'asd_code', 'begin_code', 'domain_desc', 'state_fips_code'],
#       dtype='object')

# %%
usda_df.reset_index(inplace=True)
usda_df = usda_df.rename(columns = {'index': 'survey_id'})
usda_df.reset_index(drop=True)
usda_df
# Out:
#        survey_id location_desc       prodn_practice_desc week_ending  \
# 0              0       ALABAMA  ALL PRODUCTION PRACTICES
# 1              1       ALABAMA  ALL PRODUCTION PRACTICES
# 2              2       ALABAMA  ALL PRODUCTION PRACTICES
# 3              3       ARIZONA  ALL PRODUCTION PRACTICES
# 4              4       ARIZONA  ALL PRODUCTION PRACTICES
# ...          ...           ...                       ...         ...
# 21637      21637  OTHER STATES                 RENOVATED
# 21638      21638  OTHER STATES                 RENOVATED
# 21639      21639  OTHER STATES                 RENOVATED
# 21640      21640  OTHER STATES                 RENOVATED
# 21641      21641  OTHER STATES                 RENOVATED
#
#         country_name    state_name domaincat_desc            load_time  \
# 0      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 1      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 2      UNITED STATES       ALABAMA  NOT SPECIFIED  2020-03-19 15:06:59
# 3      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# 4      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# ...              ...           ...            ...                  ...
# 21637  UNITED STATES  OTHER STATES  NOT SPECIFIED  2017-08-01 15:00:29
# 21638  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21639  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21640  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21641  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
#
#       end_code group_desc  ... county_code zip_5  year county_name  \
# 0           00  SPECIALTY  ...                    2020
# 1           00  SPECIALTY  ...                    2019
# 2           00  SPECIALTY  ...                    2018
# 3           00  SPECIALTY  ...                    2020
# 4           00  SPECIALTY  ...                    2019
# ...        ...        ...  ...         ...   ...   ...         ...
# 21637       12  SPECIALTY  ...                    2016
# 21638       03  SPECIALTY  ...                    2015
# 21639       06  SPECIALTY  ...                    2015
# 21640       09  SPECIALTY  ...                    2015
# 21641       12  SPECIALTY  ...                    2015
#
#       congr_district_code CV (%) asd_code begin_code domain_desc  \
# 0                                                 00       TOTAL
# 1                                                 00       TOTAL
# 2                                                 00       TOTAL
# 3                                                 00       TOTAL
# 4                                                 00       TOTAL
# ...                   ...    ...      ...        ...         ...
# 21637                                             10       TOTAL
# 21638                                             01       TOTAL
# 21639                                             04       TOTAL
# 21640                                             07       TOTAL
# 21641                                             10       TOTAL
#
#       state_fips_code
# 0                  01
# 1                  01
# 2                  01
# 3                  04
# 4                  04
# ...               ...
# 21637              98
# 21638              98
# 21639              98
# 21640              98
# 21641              98
#
# [21642 rows x 40 columns]

# %%
# concatenating the columns
usda_df['marketing_id'] = usda_df['reference_period_desc'].map(str) + usda_df['state_alpha'].map(str)+usda_df['year'].map(str)
usda_df
# Out:
#        survey_id location_desc       prodn_practice_desc week_ending  \
# 0              0       ALABAMA  ALL PRODUCTION PRACTICES
# 1              1       ALABAMA  ALL PRODUCTION PRACTICES
# 2              2       ALABAMA  ALL PRODUCTION PRACTICES
# 3              3       ARIZONA  ALL PRODUCTION PRACTICES
# 4              4       ARIZONA  ALL PRODUCTION PRACTICES
# ...          ...           ...                       ...         ...
# 21637      21637  OTHER STATES                 RENOVATED
# 21638      21638  OTHER STATES                 RENOVATED
# 21639      21639  OTHER STATES                 RENOVATED
# 21640      21640  OTHER STATES                 RENOVATED
# 21641      21641  OTHER STATES                 RENOVATED
#
#         country_name    state_name domaincat_desc            load_time  \
# 0      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 1      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 2      UNITED STATES       ALABAMA  NOT SPECIFIED  2020-03-19 15:06:59
# 3      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# 4      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# ...              ...           ...            ...                  ...
# 21637  UNITED STATES  OTHER STATES  NOT SPECIFIED  2017-08-01 15:00:29
# 21638  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21639  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21640  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21641  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
#
#       end_code group_desc  ... zip_5  year county_name congr_district_code  \
# 0           00  SPECIALTY  ...        2020
# 1           00  SPECIALTY  ...        2019
# 2           00  SPECIALTY  ...        2018
# 3           00  SPECIALTY  ...        2020
# 4           00  SPECIALTY  ...        2019
# ...        ...        ...  ...   ...   ...         ...                 ...
# 21637       12  SPECIALTY  ...        2016
# 21638       03  SPECIALTY  ...        2015
# 21639       06  SPECIALTY  ...        2015
# 21640       09  SPECIALTY  ...        2015
# 21641       12  SPECIALTY  ...        2015
#
#       CV (%) asd_code begin_code domain_desc state_fips_code  \
# 0                             00       TOTAL              01
# 1                             00       TOTAL              01
# 2                             00       TOTAL              01
# 3                             00       TOTAL              04
# 4                             00       TOTAL              04
# ...      ...      ...        ...         ...             ...
# 21637                         10       TOTAL              98
# 21638                         01       TOTAL              98
# 21639                         04       TOTAL              98
# 21640                         07       TOTAL              98
# 21641                         10       TOTAL              98
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 41 columns]

# %%
usda_df['value'] = usda_df['Value']

usda_df
# Out:
#        survey_id location_desc       prodn_practice_desc week_ending  \
# 0              0       ALABAMA  ALL PRODUCTION PRACTICES
# 1              1       ALABAMA  ALL PRODUCTION PRACTICES
# 2              2       ALABAMA  ALL PRODUCTION PRACTICES
# 3              3       ARIZONA  ALL PRODUCTION PRACTICES
# 4              4       ARIZONA  ALL PRODUCTION PRACTICES
# ...          ...           ...                       ...         ...
# 21637      21637  OTHER STATES                 RENOVATED
# 21638      21638  OTHER STATES                 RENOVATED
# 21639      21639  OTHER STATES                 RENOVATED
# 21640      21640  OTHER STATES                 RENOVATED
# 21641      21641  OTHER STATES                 RENOVATED
#
#         country_name    state_name domaincat_desc            load_time  \
# 0      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 1      UNITED STATES       ALABAMA  NOT SPECIFIED  2021-03-18 15:00:29
# 2      UNITED STATES       ALABAMA  NOT SPECIFIED  2020-03-19 15:06:59
# 3      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# 4      UNITED STATES       ARIZONA  NOT SPECIFIED  2021-03-18 15:00:29
# ...              ...           ...            ...                  ...
# 21637  UNITED STATES  OTHER STATES  NOT SPECIFIED  2017-08-01 15:00:29
# 21638  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21639  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21640  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
# 21641  UNITED STATES  OTHER STATES  NOT SPECIFIED  2016-05-12 15:09:03
#
#       end_code group_desc  ...  year county_name congr_district_code CV (%)  \
# 0           00  SPECIALTY  ...  2020
# 1           00  SPECIALTY  ...  2019
# 2           00  SPECIALTY  ...  2018
# 3           00  SPECIALTY  ...  2020
# 4           00  SPECIALTY  ...  2019
# ...        ...        ...  ...   ...         ...                 ...    ...
# 21637       12  SPECIALTY  ...  2016
# 21638       03  SPECIALTY  ...  2015
# 21639       06  SPECIALTY  ...  2015
# 21640       09  SPECIALTY  ...  2015
# 21641       12  SPECIALTY  ...  2015
#
#       asd_code begin_code domain_desc state_fips_code          marketing_id  \
# 0                      00       TOTAL              01  MARKETING YEARAL2020
# 1                      00       TOTAL              01  MARKETING YEARAL2019
# 2                      00       TOTAL              01  MARKETING YEARAL2018
# 3                      00       TOTAL              04  MARKETING YEARAZ2020
# 4                      00       TOTAL              04  MARKETING YEARAZ2019
# ...        ...        ...         ...             ...                   ...
# 21637                  10       TOTAL              98    OCT THRU DECOT2016
# 21638                  01       TOTAL              98    JAN THRU MAROT2015
# 21639                  04       TOTAL              98    APR THRU JUNOT2015
# 21640                  07       TOTAL              98    JUL THRU SEPOT2015
# 21641                  10       TOTAL              98    OCT THRU DECOT2015
#
#       value
# 0      5.43
# 1      3.38
# 2      3.72
# 3      2.18
# 4      2.04
# ...     ...
# 21637     0
# 21638     2
# 21639    18
# 21640     6
# 21641     0
#
# [21642 rows x 42 columns]

# %%
usda_df.dropna(inplace=True)

# %%
usda_location = usda_df[['country_name', 'country_code', 'state_name', 'state_alpha','state_fips_code', 'marketing_id']]
usda_location
# Out:
#         country_name country_code    state_name state_alpha state_fips_code  \
# 0      UNITED STATES         9000       ALABAMA          AL              01
# 1      UNITED STATES         9000       ALABAMA          AL              01
# 2      UNITED STATES         9000       ALABAMA          AL              01
# 3      UNITED STATES         9000       ARIZONA          AZ              04
# 4      UNITED STATES         9000       ARIZONA          AZ              04
# ...              ...          ...           ...         ...             ...
# 21637  UNITED STATES         9000  OTHER STATES          OT              98
# 21638  UNITED STATES         9000  OTHER STATES          OT              98
# 21639  UNITED STATES         9000  OTHER STATES          OT              98
# 21640  UNITED STATES         9000  OTHER STATES          OT              98
# 21641  UNITED STATES         9000  OTHER STATES          OT              98
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %%
usda_period = usda_df[['survey_id','freq_desc','year','load_time','state_name', 'marketing_id']]
usda_period
# Out:
#        survey_id freq_desc  year            load_time    state_name  \
# 0              0    ANNUAL  2020  2021-03-18 15:00:29       ALABAMA
# 1              1    ANNUAL  2019  2021-03-18 15:00:29       ALABAMA
# 2              2    ANNUAL  2018  2020-03-19 15:06:59       ALABAMA
# 3              3    ANNUAL  2020  2021-03-18 15:00:29       ARIZONA
# 4              4    ANNUAL  2019  2021-03-18 15:00:29       ARIZONA
# ...          ...       ...   ...                  ...           ...
# 21637      21637   MONTHLY  2016  2017-08-01 15:00:29  OTHER STATES
# 21638      21638   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21639      21639   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21640      21640   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
# 21641      21641   MONTHLY  2015  2016-05-12 15:09:03  OTHER STATES
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %%
usda_product = usda_df[['survey_id','sector_desc','class_desc','group_desc','commodity_desc', 'marketing_id']]
usda_product
# Out:
#        survey_id         sector_desc    class_desc group_desc commodity_desc  \
# 0              0  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 1              1  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 2              2  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 3              3  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# 4              4  ANIMALS & PRODUCTS   ALL CLASSES  SPECIALTY          HONEY
# ...          ...                 ...           ...        ...            ...
# 21637      21637  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21638      21638  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21639      21639  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21640      21640  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
# 21641      21641  ANIMALS & PRODUCTS  BEE COLONIES  SPECIALTY          HONEY
#
#                marketing_id
# 0      MARKETING YEARAL2020
# 1      MARKETING YEARAL2019
# 2      MARKETING YEARAL2018
# 3      MARKETING YEARAZ2020
# 4      MARKETING YEARAZ2019
# ...                     ...
# 21637    OCT THRU DECOT2016
# 21638    JAN THRU MAROT2015
# 21639    APR THRU JUNOT2015
# 21640    JUL THRU SEPOT2015
# 21641    OCT THRU DECOT2015
#
# [21642 rows x 6 columns]

# %%
#General dataframe for loss of bees
usda_causes_df=usda_df[['survey_id','value', 'domain_desc', 'unit_desc','short_desc','statisticcat_desc', 'marketing_id']]
usda_causes_df['short_desc'].unique()
# Out:
# array(['HONEY - PRICE RECEIVED, MEASURED IN $ / LB',
#        'HONEY - PRICE RECEIVED, MEASURED IN CENTS / LB',
#        'HONEY - PRODUCTION, MEASURED IN $',
#        'HONEY - PRODUCTION, MEASURED IN LB',
#        'HONEY - PRODUCTION, MEASURED IN LB / COLONY',
#        'HONEY - STOCKS, MEASURED IN LB',
#        'HONEY, BEE COLONIES, AFFECTED BY DISEASE - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL VARROA MITES)) - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES - ADDED & REPLACED, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DISORDER, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN PCT OF COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN COLONIES',
#        'HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN PCT OF COLONIES'],
#       dtype=object)

# %%
#Extracted data with CCD for 2020 year (90 rows, 8 columns)
usda_ccd_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("COLONY COLLAPSE DISORDER")]
#Removed "," from value columns
usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
#converted value column in CCD 2020 from str to float
usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
usda_ccd_df
# Out:
# <ipython-input-165-e4a67f062738>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value']=usda_ccd_df['value'].str.replace(',','')
# <ipython-input-165-e4a67f062738>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_ccd_df['value'] = usda_ccd_df['value'].astype(float)
#        survey_id   value domain_desc unit_desc  \
# 17562      17562    70.0       TOTAL  COLONIES
# 17563      17563   410.0       TOTAL  COLONIES
# 17564      17564   140.0       TOTAL  COLONIES
# 17565      17565   180.0       TOTAL  COLONIES
# 17566      17566   110.0       TOTAL  COLONIES
# ...          ...     ...         ...       ...
# 17785      17785  1100.0       TOTAL  COLONIES
# 17786      17786  1500.0       TOTAL  COLONIES
# 17787      17787   140.0       TOTAL  COLONIES
# 17788      17788     0.0       TOTAL  COLONIES
# 17789      17789     0.0       TOTAL  COLONIES
#
#                                               short_desc  \
# 17562  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17563  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17564  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17565  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17566  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# ...                                                  ...
# 17785  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17786  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17787  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17788  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
# 17789  HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DI...
#
#                     statisticcat_desc        marketing_id
# 17562  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2020
# 17563  LOSS, COLONY COLLAPSE DISORDER  APR THRU JUNAL2020
# 17564  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MARAL2019
# 17565  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPAL2019
# 17566  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECAL2019
# ...                               ...                 ...
# 17785  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPWY2019
# 17786  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECWY2019
# 17787  LOSS, COLONY COLLAPSE DISORDER  JAN THRU MAROT2019
# 17788  LOSS, COLONY COLLAPSE DISORDER  JUL THRU SEPOT2019
# 17789  LOSS, COLONY COLLAPSE DISORDER  OCT THRU DECOT2019
#
# [228 rows x 7 columns]

# %%
usda_pests_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTS")]
#Removed "," from value columns
usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
usda_pests_df
# Out:
# <ipython-input-166-ff02664a4ac4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value']=usda_pests_df['value'].str.replace(',','')
# <ipython-input-166-ff02664a4ac4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pests_df['value'] = pd.to_numeric(usda_pests_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 10288      10288    3.4       TOTAL  PCT OF COLONIES
# 10289      10289   18.0       TOTAL  PCT OF COLONIES
# 10290      10290   22.7       TOTAL  PCT OF COLONIES
# 10291      10291   24.6       TOTAL  PCT OF COLONIES
# 10292      10292   26.7       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 11249      11249    9.3       TOTAL  PCT OF COLONIES
# 11250      11250    0.1       TOTAL  PCT OF COLONIES
# 11251      11251    9.1       TOTAL  PCT OF COLONIES
# 11252      11252    0.2       TOTAL  PCT OF COLONIES
# 11253      11253    0.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 10288  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10289  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10290  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10291  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 10292  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# ...                                                  ...               ...
# 11249  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11250  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11251  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11252  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
# 11253  HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL ...         INVENTORY
#
#              marketing_id
# 10288  JAN THRU MARAL2020
# 10289  APR THRU JUNAL2020
# 10290  JAN THRU MARAL2019
# 10291  JUL THRU SEPAL2019
# 10292  OCT THRU DECAL2019
# ...                   ...
# 11249  OCT THRU DECOT2016
# 11250  JAN THRU MAROT2015
# 11251  APR THRU JUNOT2015
# 11252  JUL THRU SEPOT2015
# 11253  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_inventory_max_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("INVENTORY, MAX,")]
#Removed "," from value columns
usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
usda_inventory_max_df
# Out:
# <ipython-input-167-a01d5d0615b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value']=usda_inventory_max_df['value'].str.replace(',','')
# <ipython-input-167-a01d5d0615b7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_inventory_max_df['value'] = pd.to_numeric(usda_inventory_max_df['value'], errors='coerce')
#        survey_id  value domain_desc unit_desc  \
# 16596      16596   8000       TOTAL  COLONIES
# 16597      16597   8500       TOTAL  COLONIES
# 16598      16598   5500       TOTAL  COLONIES
# 16599      16599   7000       TOTAL  COLONIES
# 16600      16600   6000       TOTAL  COLONIES
# ...          ...    ...         ...       ...
# 17557      17557   6460       TOTAL  COLONIES
# 17558      17558   8990       TOTAL  COLONIES
# 17559      17559  11200       TOTAL  COLONIES
# 17560      17560  12280       TOTAL  COLONIES
# 17561      17561  12560       TOTAL  COLONIES
#
#                                               short_desc statisticcat_desc  \
# 16596  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16597  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16598  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16599  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 16600  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# ...                                                  ...               ...
# 17557  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17558  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17559  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17560  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
# 17561  HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED...    INVENTORY, MAX
#
#              marketing_id
# 16596  JAN THRU MARAL2020
# 16597  APR THRU JUNAL2020
# 16598  JAN THRU MARAL2019
# 16599  JUL THRU SEPAL2019
# 16600  OCT THRU DECAL2019
# ...                   ...
# 17557  OCT THRU DECOT2016
# 17558  JAN THRU MAROT2015
# 17559  APR THRU JUNOT2015
# 17560  JUL THRU SEPOT2015
# 17561  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_other_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY OTHER CAUSES")]
#Removed "," from value columns
usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')
usda_other_causes_df
# Out:
# <ipython-input-168-7183846d9813>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value']=usda_other_causes_df['value'].str.replace(',','')
# <ipython-input-168-7183846d9813>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_other_causes_df['value'] = pd.to_numeric(usda_other_causes_df['value'], errors='coerce')
#       survey_id  value domain_desc        unit_desc  \
# 8356       8356    1.7       TOTAL  PCT OF COLONIES
# 8357       8357    7.9       TOTAL  PCT OF COLONIES
# 8358       8358    3.1       TOTAL  PCT OF COLONIES
# 8359       8359    9.7       TOTAL  PCT OF COLONIES
# 8360       8360    9.0       TOTAL  PCT OF COLONIES
# ...         ...    ...         ...              ...
# 9317       9317    2.3       TOTAL  PCT OF COLONIES
# 9318       9318    0.9       TOTAL  PCT OF COLONIES
# 9319       9319    0.1       TOTAL  PCT OF COLONIES
# 9320       9320    0.7       TOTAL  PCT OF COLONIES
# 9321       9321    0.0       TOTAL  PCT OF COLONIES
#
#                                              short_desc statisticcat_desc  \
# 8356  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8357  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8358  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8359  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 8360  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# ...                                                 ...               ...
# 9317  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9318  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9319  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9320  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
# 9321  HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES ...         INVENTORY
#
#             marketing_id
# 8356  JAN THRU MARAL2020
# 8357  APR THRU JUNAL2020
# 8358  JAN THRU MARAL2019
# 8359  JUL THRU SEPAL2019
# 8360  OCT THRU DECAL2019
# ...                  ...
# 9317  OCT THRU DECOT2016
# 9318  JAN THRU MAROT2015
# 9319  APR THRU JUNOT2015
# 9320  JUL THRU SEPOT2015
# 9321  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_pesticides_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY PESTICIDES")]
#Removed "," from value columns
usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')
usda_pesticides_df
# Out:
# <ipython-input-169-0add36e41b6d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value']=usda_pesticides_df['value'].str.replace(',','')
# <ipython-input-169-0add36e41b6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_pesticides_df['value'] = pd.to_numeric(usda_pesticides_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 9322        9322    0.1       TOTAL  PCT OF COLONIES
# 9323        9323    7.7       TOTAL  PCT OF COLONIES
# 9324        9324    0.3       TOTAL  PCT OF COLONIES
# 9325        9325    0.2       TOTAL  PCT OF COLONIES
# 9326        9326    4.9       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 10283      10283    9.6       TOTAL  PCT OF COLONIES
# 10284      10284    0.1       TOTAL  PCT OF COLONIES
# 10285      10285    0.0       TOTAL  PCT OF COLONIES
# 10286      10286    0.4       TOTAL  PCT OF COLONIES
# 10287      10287    0.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 9322   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9323   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9324   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9325   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 9326   HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# ...                                                  ...               ...
# 10283  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10284  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10285  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10286  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
# 10287  HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - ...         INVENTORY
#
#              marketing_id
# 9322   JAN THRU MARAL2020
# 9323   APR THRU JUNAL2020
# 9324   JAN THRU MARAL2019
# 9325   JUL THRU SEPAL2019
# 9326   OCT THRU DECAL2019
# ...                   ...
# 10283  OCT THRU DECOT2016
# 10284  JAN THRU MAROT2015
# 10285  APR THRU JUNOT2015
# 10286  JUL THRU SEPOT2015
# 10287  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_disease_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY DISEASE")]
#Removed "," from value columns
usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
usda_disease_df.dropna(inplace=True)
usda_disease_df
# Out:
# <ipython-input-170-c4308274e7e7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value']=usda_disease_df['value'].str.replace(',','')
# <ipython-input-170-c4308274e7e7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df['value'] = pd.to_numeric(usda_disease_df['value'], errors='coerce')
# <ipython-input-170-c4308274e7e7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_disease_df.dropna(inplace=True)
#       survey_id  value domain_desc        unit_desc  \
# 7391       7391    1.6       TOTAL  PCT OF COLONIES
# 7392       7392    1.8       TOTAL  PCT OF COLONIES
# 7393       7393    2.9       TOTAL  PCT OF COLONIES
# 7394       7394    0.6       TOTAL  PCT OF COLONIES
# 7395       7395    1.9       TOTAL  PCT OF COLONIES
# ...         ...    ...         ...              ...
# 8351       8351    9.3       TOTAL  PCT OF COLONIES
# 8352       8352    0.0       TOTAL  PCT OF COLONIES
# 8353       8353    0.0       TOTAL  PCT OF COLONIES
# 8354       8354    0.0       TOTAL  PCT OF COLONIES
# 8355       8355    0.0       TOTAL  PCT OF COLONIES
#
#                                              short_desc statisticcat_desc  \
# 7391  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7392  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7393  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7394  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 7395  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# ...                                                 ...               ...
# 8351  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8352  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8353  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8354  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
# 8355  HONEY, BEE COLONIES, AFFECTED BY DISEASE - INV...         INVENTORY
#
#             marketing_id
# 7391  APR THRU JUNAL2020
# 7392  JAN THRU MARAL2019
# 7393  JUL THRU SEPAL2019
# 7394  OCT THRU DECAL2019
# 7395  JAN THRU MARAL2018
# ...                  ...
# 8351  OCT THRU DECOT2016
# 8352  JAN THRU MAROT2015
# 8353  APR THRU JUNOT2015
# 8354  JUL THRU SEPOT2015
# 8355  OCT THRU DECOT2015
#
# [946 rows x 7 columns]

# %%
usda_varroa_mites_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY VARROA MITES")]
#Removed "," from value columns
usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
usda_varroa_mites_df
# Out:
# <ipython-input-171-a377c11b86e0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value']=usda_varroa_mites_df['value'].str.replace(',','')
# <ipython-input-171-a377c11b86e0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_varroa_mites_df['value'] = pd.to_numeric(usda_varroa_mites_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 12220      12220   12.4       TOTAL  PCT OF COLONIES
# 12221      12221   28.5       TOTAL  PCT OF COLONIES
# 12222      12222   27.2       TOTAL  PCT OF COLONIES
# 12223      12223   30.6       TOTAL  PCT OF COLONIES
# 12224      12224   46.7       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 13181      13181   24.1       TOTAL  PCT OF COLONIES
# 13182      13182    0.8       TOTAL  PCT OF COLONIES
# 13183      13183   36.3       TOTAL  PCT OF COLONIES
# 13184      13184    8.8       TOTAL  PCT OF COLONIES
# 13185      13185    8.2       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 12220  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12221  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12222  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12223  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 12224  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# ...                                                  ...               ...
# 13181  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13182  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13183  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13184  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
# 13185  HONEY, BEE COLONIES, AFFECTED BY VARROA MITES ...         INVENTORY
#
#              marketing_id
# 12220  JAN THRU MARAL2020
# 12221  APR THRU JUNAL2020
# 12222  JAN THRU MARAL2019
# 12223  JUL THRU SEPAL2019
# 12224  OCT THRU DECAL2019
# ...                   ...
# 13181  OCT THRU DECOT2016
# 13182  JAN THRU MAROT2015
# 13183  APR THRU JUNOT2015
# 13184  JUL THRU SEPOT2015
# 13185  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
usda_unknown_causes_df = usda_causes_df[usda_causes_df['short_desc'].str.contains("AFFECTED BY UNKNOWN CAUSES")]
#Removed "," from value columns
usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
#converted value column in pests from str to float
usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')
usda_unknown_causes_df
# Out:
# <ipython-input-172-c2232f0d4a40>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value']=usda_unknown_causes_df['value'].str.replace(',','')
# <ipython-input-172-c2232f0d4a40>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usda_unknown_causes_df['value'] = pd.to_numeric(usda_unknown_causes_df['value'], errors='coerce')
#        survey_id  value domain_desc        unit_desc  \
# 11254      11254    4.3       TOTAL  PCT OF COLONIES
# 11255      11255    9.5       TOTAL  PCT OF COLONIES
# 11256      11256    9.0       TOTAL  PCT OF COLONIES
# 11257      11257    6.4       TOTAL  PCT OF COLONIES
# 11258      11258   11.3       TOTAL  PCT OF COLONIES
# ...          ...    ...         ...              ...
# 12215      12215    1.4       TOTAL  PCT OF COLONIES
# 12216      12216    0.0       TOTAL  PCT OF COLONIES
# 12217      12217    0.0       TOTAL  PCT OF COLONIES
# 12218      12218    0.2       TOTAL  PCT OF COLONIES
# 12219      12219    8.0       TOTAL  PCT OF COLONIES
#
#                                               short_desc statisticcat_desc  \
# 11254  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11255  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11256  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11257  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 11258  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# ...                                                  ...               ...
# 12215  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12216  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12217  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12218  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
# 12219  HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSE...         INVENTORY
#
#              marketing_id
# 11254  JAN THRU MARAL2020
# 11255  APR THRU JUNAL2020
# 11256  JAN THRU MARAL2019
# 11257  JUL THRU SEPAL2019
# 11258  OCT THRU DECAL2019
# ...                   ...
# 12215  OCT THRU DECOT2016
# 12216  JAN THRU MAROT2015
# 12217  APR THRU JUNOT2015
# 12218  JUL THRU SEPOT2015
# 12219  OCT THRU DECOT2015
#
# [966 rows x 7 columns]

# %%
import requests
import numpy as np
import pandas as pd
import time
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats
import psycopg2
import time
import pandas as pd
from sqlalchemy import create_engine
import psycopg2.extras as extras
import io

# %%
#connecting python to postgres sql
#loopback host ip="127.0.0.1". can also be used to be specific.

# %%
def load(df, name):
    engine = create_engine('postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/Bee2')

    df.head(0).to_sql( name, engine, if_exists='replace',index=False) #drops old table and creates new empty table

    conn = engine.raw_connection()
    cur = conn.cursor()
    output = io.StringIO()
    df.to_csv(output, sep='\t', header=False, index=False)
    output.seek(0)
    contents = output.getvalue()
    cur.copy_from(output, name, null="") # null values become ''
    conn.commit()
    print(str(name) + ' done')

# %%
usda_location.to_csv('location.csv', index=False)
usda_period.to_csv('period.csv', index=False)
usda_product.to_csv('product.csv', index=False)
usda_ccd_df.to_csv('ccd.csv', index=False)
usda_pests_df.to_csv('pests.csv', index=False)
usda_inventory_max_df.to_csv('inventory_max.csv', index=False)
usda_other_causes_df.to_csv('other_causes.csv', index=False)
usda_pesticides_df.to_csv('pesticides.csv', index=False)
usda_disease_df.to_csv('disease.csv', index=False)
usda_unknown_causes_df.to_csv('unknown_causes.csv', index=False)
usda_varroa_mites_df.to_csv('varroa_mites.csv', index=False)

# %%
load(usda_period, 'period')
load(usda_product, 'product')
load(usda_ccd_df, 'colony_collapse_disorder')
load(usda_inventory_max_df, 'inventory_max')
load(usda_other_causes_df, 'other_causes')
load(usda_pests_df, 'pests')
load(usda_varroa_mites_df, 'varroa_mites')
load(usda_unknown_causes_df, 'unknown_causes')
load(usda_pesticides_df, 'pesticides')
load(usda_disease_df, 'disease')
load(usda_location, 'location')
# Out:
# period done
# product done
# colony_collapse_disorder done
# inventory_max done
# other_causes done
# pests done
# varroa_mites done
# unknown_causes done
# pesticides done
# disease done
# location done
