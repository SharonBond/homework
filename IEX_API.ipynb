# %%
##import pip
##pip.main(["install", "pyEX"])
##import pyEx

# %%
from api_keys import stock_key
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
from datetime import datetime

from pprint import pprint #formats json

# %%
import pyEX as p
c = p.Client(api_token=stock_key, version='stable')

# %%
c = p.Client(api_token=stock_key, version='stable')
c.chartDF('TWTR')
# Out:
#             close    high    low   open symbol    volume                 id  \
# date
# 2021-04-16  70.12  72.200  69.68  71.97   TWTR   9429919  HISTORICAL_PRICES
# 2021-04-15  71.71  71.880  70.17  70.55   TWTR  11108264  HISTORICAL_PRICES
# 2021-04-14  69.74  73.218  69.50  72.51   TWTR  12931247  HISTORICAL_PRICES
# 2021-04-13  72.45  72.780  70.73  71.72   TWTR   9991652  HISTORICAL_PRICES
# 2021-04-12  70.86  71.840  69.65  70.87   TWTR   9495153  HISTORICAL_PRICES
# 2021-04-09  71.19  71.450  69.91  70.35   TWTR  15659504  HISTORICAL_PRICES
# 2021-04-08  71.22  71.450  69.28  69.91   TWTR  16843412  HISTORICAL_PRICES
# 2021-04-07  68.99  69.970  66.08  66.64   TWTR  23964608  HISTORICAL_PRICES
# 2021-04-06  67.00  67.650  64.30  64.67   TWTR  15587872  HISTORICAL_PRICES
# 2021-04-05  64.24  64.340  61.81  64.14   TWTR  15502130  HISTORICAL_PRICES
# 2021-04-01  63.83  66.360  63.64  64.68   TWTR  15261032  HISTORICAL_PRICES
# 2021-03-31  63.63  64.980  63.27  63.98   TWTR  14479759  HISTORICAL_PRICES
# 2021-03-30  62.99  64.100  61.90  62.30   TWTR  12533312  HISTORICAL_PRICES
# 2021-03-29  62.94  64.960  61.71  62.00   TWTR  22034480  HISTORICAL_PRICES
# 2021-03-26  61.26  61.870  59.28  61.52   TWTR  15582643  HISTORICAL_PRICES
# 2021-03-25  61.20  62.010  59.57  60.20   TWTR  19197217  HISTORICAL_PRICES
# 2021-03-24  62.06  64.950  62.05  64.95   TWTR  15475524  HISTORICAL_PRICES
# 2021-03-23  64.27  65.630  64.11  65.15   TWTR  17788626  HISTORICAL_PRICES
# 2021-03-22  65.21  66.890  64.35  66.89   TWTR  24123797  HISTORICAL_PRICES
#
#              key subkey             updated  ...   uLow   uVolume  fOpen  \
# date                                         ...
# 2021-04-16  TWTR        2021-04-17 01:16:29  ...  69.68   9429919  71.97
# 2021-04-15  TWTR        2021-04-16 00:48:31  ...  70.17  11108264  70.55
# 2021-04-14  TWTR        2021-04-15 00:48:31  ...  69.50  12931247  72.51
# 2021-04-13  TWTR        2021-04-14 00:48:32  ...  70.73   9991652  71.72
# 2021-04-12  TWTR        2021-04-13 01:00:38  ...  69.65   9495153  70.87
# 2021-04-09  TWTR        2021-04-10 01:16:29  ...  69.91  15659504  70.35
# 2021-04-08  TWTR        2021-04-09 01:01:43  ...  69.28  16843412  69.91
# 2021-04-07  TWTR        2021-04-08 00:48:32  ...  66.08  23964608  66.64
# 2021-04-06  TWTR        2021-04-07 01:00:32  ...  64.30  15587872  64.67
# 2021-04-05  TWTR        2021-04-06 00:48:31  ...  61.81  15502130  64.14
# 2021-04-01  TWTR        2021-04-02 00:48:26  ...  63.64  15261032  64.68
# 2021-03-31  TWTR        2021-04-01 00:48:30  ...  63.27  14479759  63.98
# 2021-03-30  TWTR        2021-03-31 01:16:33  ...  61.90  12533312  62.30
# 2021-03-29  TWTR        2021-03-30 01:00:28  ...  61.71  22034480  62.00
# 2021-03-26  TWTR        2021-03-27 01:16:32  ...  59.28  15582643  61.52
# 2021-03-25  TWTR        2021-03-26 00:48:27  ...  59.57  19197217  60.20
# 2021-03-24  TWTR        2021-03-25 00:48:30  ...  62.05  15475524  64.95
# 2021-03-23  TWTR        2021-03-24 01:00:18  ...  64.11  17788626  65.15
# 2021-03-22  TWTR        2021-03-23 00:48:28  ...  64.35  24123797  66.89
#
#             fClose   fHigh   fLow   fVolume       label  change  changePercent
# date
# 2021-04-16   70.12  72.200  69.68   9429919  Apr 16, 21    0.00         0.0000
# 2021-04-15   71.71  71.880  70.17  11108264  Apr 15, 21    1.59         0.0227
# 2021-04-14   69.74  73.218  69.50  12931247  Apr 14, 21   -1.97        -0.0275
# 2021-04-13   72.45  72.780  70.73   9991652  Apr 13, 21    2.71         0.0389
# 2021-04-12   70.86  71.840  69.65   9495153  Apr 12, 21   -1.59        -0.0219
# 2021-04-09   71.19  71.450  69.91  15659504   Apr 9, 21    0.33         0.0047
# 2021-04-08   71.22  71.450  69.28  16843412   Apr 8, 21    0.03         0.0004
# 2021-04-07   68.99  69.970  66.08  23964608   Apr 7, 21   -2.23        -0.0313
# 2021-04-06   67.00  67.650  64.30  15587872   Apr 6, 21   -1.99        -0.0288
# 2021-04-05   64.24  64.340  61.81  15502130   Apr 5, 21   -2.76        -0.0412
# 2021-04-01   63.83  66.360  63.64  15261032   Apr 1, 21   -0.41        -0.0064
# 2021-03-31   63.63  64.980  63.27  14479759  Mar 31, 21   -0.20        -0.0031
# 2021-03-30   62.99  64.100  61.90  12533312  Mar 30, 21   -0.64        -0.0101
# 2021-03-29   62.94  64.960  61.71  22034480  Mar 29, 21   -0.05        -0.0008
# 2021-03-26   61.26  61.870  59.28  15582643  Mar 26, 21   -1.68        -0.0267
# 2021-03-25   61.20  62.010  59.57  19197217  Mar 25, 21   -0.06        -0.0010
# 2021-03-24   62.06  64.950  62.05  15475524  Mar 24, 21    0.86         0.0141
# 2021-03-23   64.27  65.630  64.11  17788626  Mar 23, 21    2.21         0.0356
# 2021-03-22   65.21  66.890  64.35  24123797  Mar 22, 21    0.94         0.0146
#
# [19 rows x 25 columns]

# %%
c.chartDF('AAPL')

# %%
##https://cloud.iexapis.com/stable/stock/FB/chart/date/20191107?token=stock_key
    
    
    # base url for getting api data
##base_url = "https://cloud.iexapis.com/stable/stock/UCO/chart/date/20190210?token=" + stock_key
#base_url = "https://cloud.iexapis.com/beta/stock/AAPL/chart/date/20200102?chartByDay=true&token="  + stock_key
base_url = "https://cloud.iexapis.com/stable/stock/"
additional_url=  "/chart/date/"
date1 = '20200102'
date2 = '20200316'
date3 = '20210316'
last_url = "?chartByDay=true&token="  + stock_key
symbol = 'AAPL'

##base_url = 
##https://cloud.iexapis.com/stable/stock/twtr/chart/date/20190109?chartByDay=true

##symbol = 'UCO'
##date = '20110106'
#base_url = "https://cloud.iexapis.com/stable/stock/" + symbol+ "/chart/date/"+ date1 +"?chartByDay=true&token=" + stock_key

a = base_url+ 'AAPL'+additional_url+date1+last_url
# example request (request.get is to get the request) - only pulls with zero index
req = requests.get(base_url+ 'AAPL'+additional_url+date1+last_url).json()
t = requests.get(a)
#data = req.json()
print(a)
print(req)
print(t)

stock = ['XOM', 'DIS', 'DRI', 'LUV', 'HLT' ]
test = (base_url+ '{stock[0]}'+additional_url+date1+last_url)#json()
##GET /stock/{symbol}/chart/{range}/{date}
# Out:
# https://cloud.iexapis.com/stable/stock/AAPL/chart/date/20200102?chartByDay=true&token=pk_603c03893595429dab5e9303276077d9
# [{'close': 75.0875, 'high': 75.15, 'low': 73.7975, 'open': 74.06, 'symbol': 'AAPL', 'volume': 135647456, 'id': 'HISTORICAL_PRICES', 'key': 'AAPL', 'subkey': '', 'date': '2020-01-02', 'updated': 1612491432000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 296.24, 'uClose': 300.35, 'uHigh': 300.6, 'uLow': 295.19, 'uVolume': 33911864, 'fOpen': 73.3163, 'fClose': 74.3335, 'fHigh': 74.3954, 'fLow': 73.0565, 'fVolume': 135647456, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}]
# <Response [200]>

# %%
stock = ['XOM', 'DIS', 'DRI', 'LUV', 'HLT' ]

# %%
stock = ['XOM', 'DIS', 'DRI', 'LUV', 'HLT' ]
stock_data = []
#for  symbol in  stock:
 #   req = requests.get(base_url+ {symbol}+additional_url+date1+last_url).json()
  #  stock_data.append(req)
req = requests.get(base_url+ 'XOM'+additional_url+date1+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DIS'+additional_url+date1+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DRI'+additional_url+date1+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'LUV'+additional_url+date1+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'HLT'+additional_url+date1+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'XOM'+additional_url+date2+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DIS'+additional_url+date2+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DRI'+additional_url+date2+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'LUV'+additional_url+date2+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'HLT'+additional_url+date2+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'XOM'+additional_url+date3+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DIS'+additional_url+date3+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'DRI'+additional_url+date3+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'LUV'+additional_url+date3+last_url).json()
stock_data.append(req)
req = requests.get(base_url+ 'HLT'+additional_url+date3+last_url).json()
stock_data.append(req)

print(stock_data)
type(stock_data)
# Out:
# [[{'close': 70.9, 'high': 71.02, 'low': 70.2368, 'open': 70.24, 'symbol': 'XOM', 'volume': 12406912, 'id': 'HISTORICAL_PRICES', 'key': 'XOM', 'subkey': '', 'date': '2020-01-02', 'updated': 1612858663000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 70.24, 'uClose': 70.9, 'uHigh': 71.02, 'uLow': 70.2368, 'uVolume': 12406912, 'fOpen': 63.9591, 'fClose': 64.5601, 'fHigh': 64.6694, 'fLow': 63.9562, 'fVolume': 12406912, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}], [{'close': 148.2, 'high': 148.2, 'low': 145.1, 'open': 145.29, 'symbol': 'DIS', 'volume': 9504711, 'id': 'HISTORICAL_PRICES', 'key': 'DIS', 'subkey': '', 'date': '2020-01-02', 'updated': 1606830572000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 145.29, 'uClose': 148.2, 'uHigh': 148.2, 'uLow': 145.1, 'uVolume': 9504711, 'fOpen': 145.29, 'fClose': 148.2, 'fHigh': 148.2, 'fLow': 145.1, 'fVolume': 9504711, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}], [{'close': 112.26, 'high': 112.26, 'low': 109.39, 'open': 109.8, 'symbol': 'DRI', 'volume': 2745683, 'id': 'HISTORICAL_PRICES', 'key': 'DRI', 'subkey': '', 'date': '2020-01-02', 'updated': 1617848222000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 109.8, 'uClose': 112.26, 'uHigh': 112.26, 'uLow': 109.39, 'uVolume': 2745683, 'fOpen': 107.6428, 'fClose': 110.0545, 'fHigh': 110.0545, 'fLow': 107.2409, 'fVolume': 2745683, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}], [{'close': 54.84, 'high': 54.87, 'low': 54.285, 'open': 54.38, 'symbol': 'LUV', 'volume': 3508411, 'id': 'HISTORICAL_PRICES', 'key': 'LUV', 'subkey': '', 'date': '2020-01-02', 'updated': 1606830572000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 54.38, 'uClose': 54.84, 'uHigh': 54.87, 'uLow': 54.285, 'uVolume': 3508411, 'fOpen': 54.1715, 'fClose': 54.6298, 'fHigh': 54.6596, 'fLow': 54.0769, 'fVolume': 3508411, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}], [{'close': 111.45, 'high': 111.62, 'low': 110.46, 'open': 111.15, 'symbol': 'HLT', 'volume': 2014639, 'id': 'HISTORICAL_PRICES', 'key': 'HLT', 'subkey': '', 'date': '2020-01-02', 'updated': 1606830572000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 111.15, 'uClose': 111.45, 'uHigh': 111.62, 'uLow': 110.46, 'uVolume': 2014639, 'fOpen': 110.9797, 'fClose': 111.2792, 'fHigh': 111.449, 'fLow': 110.2908, 'fVolume': 2014639, 'label': 'Jan 2, 20', 'change': 0, 'changePercent': 0}], [{'close': 34.49, 'high': 37.88, 'low': 33.25, 'open': 34.4, 'symbol': 'XOM', 'volume': 48924723, 'id': 'HISTORICAL_PRICES', 'key': 'XOM', 'subkey': '', 'date': '2020-03-16', 'updated': 1612858606000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 34.4, 'uClose': 34.49, 'uHigh': 37.88, 'uLow': 33.25, 'uVolume': 48924723, 'fOpen': 31.7736, 'fClose': 31.8568, 'fHigh': 34.988, 'fLow': 30.7114, 'fVolume': 48924723, 'label': 'Mar 16, 20', 'change': 0, 'changePercent': 0}], [{'close': 95.01, 'high': 98.28, 'low': 90, 'open': 91.8, 'symbol': 'DIS', 'volume': 35379527, 'id': 'HISTORICAL_PRICES', 'key': 'DIS', 'subkey': '', 'date': '2020-03-16', 'updated': 1606830572000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 91.8, 'uClose': 95.01, 'uHigh': 98.28, 'uLow': 90, 'uVolume': 35379527, 'fOpen': 91.8, 'fClose': 95.01, 'fHigh': 98.28, 'fLow': 90, 'fVolume': 35379527, 'label': 'Mar 16, 20', 'change': 0, 'changePercent': 0}], [{'close': 49.21, 'high': 58.36, 'low': 46.17, 'open': 58.24, 'symbol': 'DRI', 'volume': 4490209, 'id': 'HISTORICAL_PRICES', 'key': 'DRI', 'subkey': '', 'date': '2020-03-16', 'updated': 1617848324000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 58.24, 'uClose': 49.21, 'uHigh': 58.36, 'uLow': 46.17, 'uVolume': 4490209, 'fOpen': 57.5406, 'fClose': 48.619, 'fHigh': 57.6591, 'fLow': 45.6155, 'fVolume': 4490209, 'label': 'Mar 16, 20', 'change': 0, 'changePercent': 0}], [{'close': 37.52, 'high': 39.45, 'low': 35.85, 'open': 36.5, 'symbol': 'LUV', 'volume': 15849917, 'id': 'HISTORICAL_PRICES', 'key': 'LU ...
# list

# %%
stock_data[0][0]['symbol']
# Out:
# 'XOM'

# %%
stock_dict = {'Symbol': [], 'Date': [], 'Label': [], 'High': [], 'Low': [], 'Open': [], 'Close': []}
for x in range(len(stock_data)):
    stock_dict['Symbol'].append(stock_data[x][0]['symbol'])
    stock_dict['Date'].append(stock_data[x][0]['date'])
    stock_dict['Label'].append(stock_data[x][0]['label'])
    stock_dict['High'].append(stock_data[x][0]['high'])
    stock_dict['Low'].append(stock_data[x][0]['low'])
    stock_dict['Open'].append(stock_data[x][0]['open'])
    stock_dict['Close'].append(stock_data[x][0]['close'])

print(stock_dict)
stock_df = pd.DataFrame(stock_dict)
display(stock_df)
# Out:
# {'Symbol': ['XOM', 'DIS', 'DRI', 'LUV', 'HLT', 'XOM', 'DIS', 'DRI', 'LUV', 'HLT', 'XOM', 'DIS', 'DRI', 'LUV', 'HLT'], 'Date': ['2020-01-02', '2020-01-02', '2020-01-02', '2020-01-02', '2020-01-02', '2020-03-16', '2020-03-16', '2020-03-16', '2020-03-16', '2020-03-16', '2021-03-16', '2021-03-16', '2021-03-16', '2021-03-16', '2021-03-16'], 'Label': ['Jan 2, 20', 'Jan 2, 20', 'Jan 2, 20', 'Jan 2, 20', 'Jan 2, 20', 'Mar 16, 20', 'Mar 16, 20', 'Mar 16, 20', 'Mar 16, 20', 'Mar 16, 20', 'Mar 16, 21', 'Mar 16, 21', 'Mar 16, 21', 'Mar 16, 21', 'Mar 16, 21'], 'High': [71.02, 148.2, 112.26, 54.87, 111.62, 37.88, 98.28, 58.36, 39.45, 75.89, 59.66, 196.59, 144.45, 62.3, 127.78], 'Low': [70.2368, 145.1, 109.39, 54.285, 110.46, 33.25, 90, 46.17, 35.85, 63.83, 58.44, 192.88, 139.9222, 60.53, 123.77], 'Open': [70.24, 145.29, 109.8, 54.38, 111.15, 34.4, 91.8, 58.24, 36.5, 69.42, 59.54, 196.1, 144.25, 62.26, 127.39], 'Close': [70.9, 148.2, 112.26, 54.84, 111.45, 34.49, 95.01, 49.21, 37.52, 69.54, 59.11, 194.24, 140.54, 60.54, 123.96]}
#    Symbol        Date       Label    High       Low    Open   Close
# 0     XOM  2020-01-02   Jan 2, 20   71.02   70.2368   70.24   70.90
# 1     DIS  2020-01-02   Jan 2, 20  148.20  145.1000  145.29  148.20
# 2     DRI  2020-01-02   Jan 2, 20  112.26  109.3900  109.80  112.26
# 3     LUV  2020-01-02   Jan 2, 20   54.87   54.2850   54.38   54.84
# 4     HLT  2020-01-02   Jan 2, 20  111.62  110.4600  111.15  111.45
# 5     XOM  2020-03-16  Mar 16, 20   37.88   33.2500   34.40   34.49
# 6     DIS  2020-03-16  Mar 16, 20   98.28   90.0000   91.80   95.01
# 7     DRI  2020-03-16  Mar 16, 20   58.36   46.1700   58.24   49.21
# 8     LUV  2020-03-16  Mar 16, 20   39.45   35.8500   36.50   37.52
# 9     HLT  2020-03-16  Mar 16, 20   75.89   63.8300   69.42   69.54
# 10    XOM  2021-03-16  Mar 16, 21   59.66   58.4400   59.54   59.11
# 11    DIS  2021-03-16  Mar 16, 21  196.59  192.8800  196.10  194.24
# 12    DRI  2021-03-16  Mar 16, 21  144.45  139.9222  144.25  140.54
# 13    LUV  2021-03-16  Mar 16, 21   62.30   60.5300   62.26   60.54
# 14    HLT  2021-03-16  Mar 16, 21  127.78  123.7700  127.39  123.96

# %%
stocks = stock_df
fig, ax = plt.subplots()
ax.bar(stocks.index, stocks['High'])
ax.set_xticklabels(stocks.index, rotation = 90)
ax.set_y_label = ("Price")
plt.show()
# Out:
# <ipython-input-260-d858bc841806>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(stocks.index, rotation = 90)

# %%
stock_df.plot(kind="bar", title="test")

plt.title("Test")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
# Out:
# Text(0, 0.5, 'Pies Consumed')
